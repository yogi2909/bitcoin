# %%
# Importing the required libararies
import json # for working with JSON data
import requests # for sending request to the API endpoint/url
import statistics # for statistical calculations
import pandas as pd # for working with dataframe/tabular data
from bs4 import BeautifulSoup # for parsing html tags
from datetime import datetime # for working with datetime

# %%
# Make request to the API...
response = requests.get('https://api.coinranking.com/v1/public/coin/1/history/30d', timeout=10)
rjson = response.json()

# Use tool like: https://jsoneditoronline.org to inspect the returned json to know which node contains the required data...
# In this case the data is in: 'data' >> 'history'. That is: rjson['data']['history'] which is a list of dictionaries...

# Lets save it into a dataframe for manipulation.
df = pd.DataFrame(rjson['data']['history'])
# Now lets update the dataframe table with the schema definitions...

# **********************************************************************
# **********************************************************************
# Schema 1: The general work flow is the create a helper function and apply it to a new column...

# Date------------------
def date_func(x):
    x = int(str(x)[:-3]) # Reduce digits to 10 to avoid OSError - so convert to str and slice out
    dt = datetime.fromtimestamp(x).strftime('%Y-%m-%d T%H:%M:%S')
    return dt

df['Date'] = df['timestamp'].apply( lambda x: date_func(x) )



# Price------------------
def price_func(x):
    return round(float(x), 2) # Convert to float and round to 2 decimal

df['Price'] = df['price'].apply( lambda x: price_func(x) )



# Direction------------------
# Create a helper column by shifting price column down by 1 step
df['Direction_temp1'] = df['Price'].shift(1)

def direction_func(x, y):
    if x - y > 0:
        return 'Down'
    if x - y < 0:
        return 'Up'
    if x - y == 0:
        return 'Same'

df['Direction'] = df.apply( lambda x : direction_func(x['Direction_temp1'], x['Price']), axis=1 )


# Change------------------
def change_func(x, y):
    return x - y

df['Change'] = df.apply( lambda x : change_func(x['Direction_temp1'], x['Price']), axis=1 )



# dayOfWeek------------------
def day_of_week_func(x):
    x = int(str(x)[:-3]) # Reduce digits to 10 to avoid OSError - so convert to str and slice out
    dt = datetime.fromtimestamp(x).strftime('%A')
    return dt

df['dayOfWeek'] = df['timestamp'].apply( lambda x : day_of_week_func(x) )



# highSinceStart------------------
def high_since_start(x):
    if x == 'Up':
        return 'true'
    elif x == 'Down':
        return 'false'
    else:
        return ''

df['highSinceStart'] = df['Direction'].apply( lambda x : high_since_start(x) )




# lowSinceStart------------------
def low_since_start(x):
    if x == 'Down':
        return 'true'
    elif x == 'Up':
        return 'false'
    else:
        return ''

df['lowSinceStart'] = df['Direction'].apply( lambda x : low_since_start(x) )


# **********************************************************************
# **********************************************************************
# Schema 2: As in above, the new entries are: dailyAverage, dailyVariance, volatilityAlert

# dailyAverage------------------
# Create helper column...
df['Date_temp1'] = df['Date'].apply( lambda x : x.split(' T')[0] )
# Group the data by Date_temp1 col and cal average...
date_group = df.groupby('Date_temp1')
df_average = date_group.apply(lambda x: x['Price'].mean())
# pd.DataFrame(df2, columns=['Mean']).reset_index()
df_average = df_average.to_frame(name="Mean").reset_index()
# Map the average to the main df...
# make a mapping dictionary from average df...
avg_dict = dict(zip(df_average['Date_temp1'], round(df_average['Mean'], 2)))
# create new column based on the map column and dictionary
df['dailyAverage'] = df['Date_temp1'].map(avg_dict)




# dailyVariance------------------
# Population variance n
# dailyVariance = statistics.pvariance( df['Price'].to_list() )
# Sample variance n-1
# dailyVariance = statistics.variance( df['Price'].to_list() )

# Use the day Group df above to cal dailyVariance...
df_variance = date_group.apply( lambda x: round(statistics.variance(x['Price'].to_list()), 2) )
df_variance = df_variance.to_frame(name="Variance").reset_index()
vari_dict = dict(zip(df_variance['Date_temp1'], df_variance['Variance'] ))
df['dailyVariance'] = df['Date_temp1'].map(vari_dict)



# volatilityAlert------------------
# Standard Deviation... 
sd = round( statistics.stdev( df['Price'].to_list() ), 2) # Or: df['Price'].std()
second_sd = df['Price'].mean() + 2*sd

# median = df['Price'].median()
# percentage = (sd/median) * 100
# benchmark = 95 / 100

'''
The normal distribution is commonly associated with the 68-95-99.7 rule which you can see in the image above. 
    68% of the data is within 1 standard deviation (σ) of the mean (μ), 
    95% of the data is within 2 standard deviations (σ) of the mean (μ), and 
    99.7% of the data is within 3 standard deviations (σ) of the mean (μ).
- https://towardsdatascience.com/understanding-the-68-95-99-7-rule-for-a-normal-distribution-b7b7cbf760c2

2nd standard devation above = mean + 2*standard deviation
2nd standard deviation below = mean - 2*standard deviation
- https://www.wyzant.com/resources/answers/27347/i_need_to_find_one_two_and_three_standards_deviations_above_the_mean_over_14_88_and_one_two_and_three_below_this_mean
- https://www.cuemath.com/questions/how-to-find-how-many-standard-deviation-away-from-mean/

- "volatilityAlert:" true/false if any price that day is outside 2 standard deviations.
'''
def volatility_alert_func(x):
    if x > second_sd:
        return 'true'
    else:
        return 'false'
    
df['volatilityAlert'] = df['Price'].apply( lambda x: volatility_alert_func(x) )



# **********************************************************************
# **********************************************************************
# Filter only time at: 00:00:00
# Drop dups by date...
df_drop_dup = df.drop_duplicates(subset='Date_temp1', keep="first")


# Filter the needed fields into df_schemas as follow...
df_schema1 = df_drop_dup[['Date', 'Price', 'Direction', 'Change', 'dayOfWeek', 'highSinceStart', 'lowSinceStart']]
df_schema2 = df_drop_dup[['Date', 'Price', 'dailyAverage', 'dailyVariance', 'volatilityAlert']]


# Get current time to save json file...
current_time = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")

# Convert table to schemas...
df_schema1.to_json(f'schema_1_{current_time}.json', orient='records')
print(df_schema1.to_json(orient='records'))

df_schema2.to_json(f'schema_2_{current_time}.json', orient='records')
print(df_schema2.to_json(orient='records'))
# Out:
# [{"Date":"2021-09-17 T20:00:00","Price":47172.4,"Direction":null,"Change":null,"dayOfWeek":"Friday","highSinceStart":"","lowSinceStart":""},{"Date":"2021-09-18 T00:00:00","Price":47013.49,"Direction":"Down","Change":237.58,"dayOfWeek":"Saturday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-09-19 T00:00:00","Price":47969.43,"Direction":"Up","Change":-74.9,"dayOfWeek":"Sunday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-09-20 T00:00:00","Price":47050.53,"Direction":"Down","Change":384.05,"dayOfWeek":"Monday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-09-21 T00:00:00","Price":43269.1,"Direction":"Down","Change":299.52,"dayOfWeek":"Tuesday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-09-22 T00:00:00","Price":40704.26,"Direction":"Down","Change":760.6,"dayOfWeek":"Wednesday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-09-23 T00:00:00","Price":43548.05,"Direction":"Up","Change":-324.2,"dayOfWeek":"Thursday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-09-24 T00:00:00","Price":44879.07,"Direction":"Up","Change":-203.91,"dayOfWeek":"Friday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-09-25 T00:00:00","Price":43078.62,"Direction":"Up","Change":-115.45,"dayOfWeek":"Saturday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-09-26 T00:00:00","Price":42746.6,"Direction":"Up","Change":-66.92,"dayOfWeek":"Sunday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-09-27 T00:00:00","Price":43138.9,"Direction":"Down","Change":394.34,"dayOfWeek":"Monday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-09-28 T00:00:00","Price":43139.74,"Direction":"Up","Change":-57.59,"dayOfWeek":"Tuesday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-09-29 T00:00:00","Price":41653.35,"Direction":"Down","Change":201.96,"dayOfWeek":"Wednesday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-09-30 T00:00:00","Price":41418.43,"Direction":"Up","Change":-175.84,"dayOfWeek":"Thursday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-10-01 T00:00:00","Price":43727.22,"Direction":"Up","Change":-0.22,"dayOfWeek":"Friday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-10-02 T00:00:00","Price":47977.25,"Direction":"Down","Change":236.75,"dayOfWeek":"Saturday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-10-03 T00:00:00","Price":48096.9,"Direction":"Down","Change":40.42,"dayOfWeek":"Sunday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-10-04 T00:00:00","Price":47978.96,"Direction":"Up","Change":-207.35,"dayOfWeek":"Monday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-10-05 T00:00:00","Price":48897.61,"Direction":"Up","Change":-4.5,"dayOfWeek":"Tuesday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-10-06 T00:00:00","Price":50845.55,"Direction":"Down","Change":854.19,"dayOfWeek":"Wednesday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-10-07 T00:00:00","Price":55143.27,"Direction":"Up","Change":-69.43,"dayOfWeek":"Thursday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-10-08 T00:00:00","Price":53885.09,"Direction":"Down","Change":393.18,"dayOfWeek":"Friday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-10-09 T00:00:00","Price":54096.48,"Direction":"Down","Change":99.91,"dayOfWeek":"Saturday","highSinceStart":"false","lowSinceStart":"true"},{"Date":"2021-10-10 T00:00:00","Price":54862.77,"Direction":"Up","Change":-41.92,"dayOfWeek":"Sunday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-10-11 T00:00:00","Price":54896.06,"Direction":"Up","Change":-35.1,"dayOfWeek":"Monday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-10-12 T00:00:00","Price":57224.83,"Direction":"Up","Change":-46.42,"dayOfWeek":"Tuesday","highSinceStart":"true","lowSinceStart":"false"},{"Date":"2021-10-13 T00:00:00","Price":56321 ...
# [{"Date":"2021-09-17 T20:00:00","Price":47172.4,"dailyAverage":47252.4,"dailyVariance":19889.82,"volatilityAlert":"false"},{"Date":"2021-09-18 T00:00:00","Price":47013.49,"dailyAverage":48143.87,"dailyVariance":224405.6,"volatilityAlert":"false"},{"Date":"2021-09-19 T00:00:00","Price":47969.43,"dailyAverage":47744.87,"dailyVariance":91712.07,"volatilityAlert":"false"},{"Date":"2021-09-20 T00:00:00","Price":47050.53,"dailyAverage":44897.53,"dailyVariance":1705289.1399999999,"volatilityAlert":"false"},{"Date":"2021-09-21 T00:00:00","Price":43269.1,"dailyAverage":42644.77,"dailyVariance":445605.48,"volatilityAlert":"false"},{"Date":"2021-09-22 T00:00:00","Price":40704.26,"dailyAverage":42343.01,"dailyVariance":643183.1899999999,"volatilityAlert":"false"},{"Date":"2021-09-23 T00:00:00","Price":43548.05,"dailyAverage":44016.0,"dailyVariance":201259.99,"volatilityAlert":"false"},{"Date":"2021-09-24 T00:00:00","Price":44879.07,"dailyAverage":43217.86,"dailyVariance":1623061.7,"volatilityAlert":"false"},{"Date":"2021-09-25 T00:00:00","Price":43078.62,"dailyAverage":42619.1,"dailyVariance":27657.09,"volatilityAlert":"false"},{"Date":"2021-09-26 T00:00:00","Price":42746.6,"dailyAverage":42760.09,"dailyVariance":445857.76,"volatilityAlert":"false"},{"Date":"2021-09-27 T00:00:00","Price":43138.9,"dailyAverage":43525.26,"dailyVariance":191445.03,"volatilityAlert":"false"},{"Date":"2021-09-28 T00:00:00","Price":43139.74,"dailyAverage":42013.45,"dailyVariance":205341.75,"volatilityAlert":"false"},{"Date":"2021-09-29 T00:00:00","Price":41653.35,"dailyAverage":41851.43,"dailyVariance":230913.49,"volatilityAlert":"false"},{"Date":"2021-09-30 T00:00:00","Price":41418.43,"dailyAverage":43110.41,"dailyVariance":362044.31,"volatilityAlert":"false"},{"Date":"2021-10-01 T00:00:00","Price":43727.22,"dailyAverage":45754.14,"dailyVariance":3451222.7799999998,"volatilityAlert":"false"},{"Date":"2021-10-02 T00:00:00","Price":47977.25,"dailyAverage":47825.71,"dailyVariance":33107.59,"volatilityAlert":"false"},{"Date":"2021-10-03 T00:00:00","Price":48096.9,"dailyAverage":47998.08,"dailyVariance":153317.75,"volatilityAlert":"false"},{"Date":"2021-10-04 T00:00:00","Price":47978.96,"dailyAverage":48050.47,"dailyVariance":396389.69,"volatilityAlert":"false"},{"Date":"2021-10-05 T00:00:00","Price":48897.61,"dailyAverage":49804.5,"dailyVariance":549901.73,"volatilityAlert":"false"},{"Date":"2021-10-06 T00:00:00","Price":50845.55,"dailyAverage":52552.36,"dailyVariance":3096998.0499999998,"volatilityAlert":"false"},{"Date":"2021-10-07 T00:00:00","Price":55143.27,"dailyAverage":54458.04,"dailyVariance":205687.76,"volatilityAlert":"false"},{"Date":"2021-10-08 T00:00:00","Price":53885.09,"dailyAverage":54423.68,"dailyVariance":306919.35,"volatilityAlert":"false"},{"Date":"2021-10-09 T00:00:00","Price":54096.48,"dailyAverage":54666.64,"dailyVariance":122597.09,"volatilityAlert":"false"},{"Date":"2021-10-10 T00:00:00","Price":54862.77,"dailyAverage":55186.76,"dailyVariance":115307.95,"volatilityAlert":"false"},{"Date":"2021-10-11 T00:00:00","Price":54896.06,"dailyAverage":56560.73,"dailyVariance":732408.25,"volatilityAlert":"false"},{"Date":"2021-10-12 T00:00:00","Price":57224.83,"dailyAverage":56713.1,"dailyVariance":427173.34,"volatilityAlert":"false"},{"Date":"2021-10-13 T00:00:00","Price":56321.04,"dailyAverage":55932.72,"dailyVariance":793977.59,"volatilityAlert":"false"},{"Date":"2021-10-14 T00:00:00","Price":57361.03,"dailyAverage":57626.18,"dailyVariance":90561.9,"volatilityAlert":"false"},{"Date":"2021-10-15 T00:00:00","Price":57618.52,"dailyAverage":59656.1,"dailyVariance":2102985.9900000002,"volatilityAlert":"false"},{"Date":"2021-10-16 T00:00:00","Price":61324.69,"dailyAverage":61273.88,"dailyVariance":193967.28,"volatilityAlert":"false"},{"Date":"2021-10-17 T00:00:00","Price":60817.38,"dailyAverage":60893.81,"dailyVariance":39664.0,"volatilityAlert":"false"}]
